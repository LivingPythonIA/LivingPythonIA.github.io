# %% [markdown]
# <a href="https://colab.research.google.com/github/LivingPythonIA/LivingPythonIA.github.io/blob/main/orientado_a_objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
fig = plt.figure()   # Creamos una figura (canvas vacío)
axes = fig.add_axes([0.1,0.1,0.5,0.9])   #  Añadimos los ejes
axes.plot(x,y,'b')     # 'b' hace referencia al color azul (blue)
fig.show()

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.9]) # eje principal (ubicacion en el lienzo, ,ancho,alto)
axes2 = fig.add_axes([0.2,0.55,0.4,0.3]) # eje interior

# Figura principal axes
axes.plot(x,y,'b')

# Inserta figura axes2
axes2.plot(y,x,'r')
axes2.set_facecolor('gray')

fig.show()
