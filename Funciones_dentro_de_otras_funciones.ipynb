# %% [markdown]
# <a href="https://colab.research.google.com/github/LivingPythonIA/LivingPythonIA.github.io/blob/main/Funciones_dentro_de_otras_funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 1000

x = np.linspace(-10,10, num=N)

def g(x):
  return x**2

y = g(x)

plt.plot(x,y)

# %%
N = 1000

x = np.linspace(-10,10, num=N)

def g(x):
  return x**2

def f(x):
  return np.sin(x)

y = f(x)


plt.plot(x,y)

# %%
N = 1000

x = np.linspace(-10,10, num=N)

def g(x):
  return x**2

def f(x):
  return np.sin(x)

y = g(x)
#composicion de funciones
f_o_g = f(y)

plt.plot(x,f_o_g)

# %%
N = 1000

x = np.linspace(-10,10, num=N)

def g(x):
  return x**2

def f(x):
  return np.sin(x)

#y = g(x)
#la ingreso como argumento directamente
f_o_g = f(g(x))

plt.plot(x,f_o_g)

# %%
N = 1000

x = np.linspace(-10,10, num=N)

def g(x):
  return x**2

def f(x):
  return np.tan(x)

f_o_g = f(g(x))

plt.plot(x,f_o_g)

# %%
N = 1000

x = np.linspace(-10,10, num=N)

def g(x):
  return x**2

def f(x):
  return np.cos(x)

f_o_g = f(g(x))

plt.plot(x,f_o_g)
