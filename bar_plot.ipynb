# %% [markdown]
# <a href="https://colab.research.google.com/github/LivingPythonIA/LivingPythonIA.github.io/blob/main/bar_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
country = ['INDIA','JAPAN','MEXICO','COLOMBIA','GERMANY']
population = [1000,800,900,1000,300]

# %%
plt.bar(country,population)
plt.show()

# %%
plt.bar(country,population,width=0.5,color=['red','blue'])
plt.title('Population of Countries')
plt.xlabel('Countries')
plt.ylabel('Population')
plt.xticks(np.arange(5),('India','Japon','Mexico','Colombia','Alemania'),rotation=45)
plt.show()

# %%
plt.barh(country,population,color=['orange','yellow'])
plt.title('Population of Countries')
plt.xlabel('Countries')
plt.ylabel('Population')
plt.show()
